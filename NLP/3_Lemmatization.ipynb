# %% [markdown]
# # Lemmatization

# %%
import nltk

# Force download the missing resource
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)
# Out:
# True

# %%
# Wordnet Lemmatizer, gives root words rather than root stem

from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
"""
POS
Noun-n
verb-v
adjective-a
adverb-r

"""


lemmatizer.lemmatize("going", pos='v')
# Out:
# 'go'

# %%
lemmatizer.lemmatize("congratulations")
# Out:
# 'congratulation'

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %%
for word in words:
    print(word+"----->"+lemmatizer.lemmatize(word,pos='n'))
# Out:
# eating----->eating
# eats----->eats
# eaten----->eaten
# writing----->writing
# writes----->writes
# programming----->programming
# programs----->program
# history----->history
# finally----->finally
# finalized----->finalized

# %%
for word in words:
    print(word+"----->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating----->eat
# eats----->eat
# eaten----->eat
# writing----->write
# writes----->write
# programming----->program
# programs----->program
# history----->history
# finally----->finally
# finalized----->finalize

# %%
# this will take more time than stemming
#
